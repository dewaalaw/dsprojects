# %% [markdown]
# <a href="https://colab.research.google.com/github/dewaalaw/dsprojects/blob/main/traffic-flow-forecast/src/traffic_flow_forecasting_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook continues from the `traffic_flow_forecast_part_1.ipynb` notebook, implementing the model architecture of a Convolutional Neural Network (CNN); a Recurrent Neural Network (RNN), notably the Long Short-Term Memory archictecture (LSTM); and lastly an Auto-regressive LSTM. To compare the performance of these model architectures for the time series data, we observe their Mean Absolute Error, keeping the train, validation, and test sets constant.
#
# For each of the above architecture, traffic volumes are forecasted for the next timestep as well as the next 24 hours. These are implemented using a single- and a multi-step model, respectively. Additionally, we create a multi-output model for each of the above architectures that predict temperature and traffic volume for the next timestep simultaneously.

# %% [markdown]
# # Development Environment

# %%
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

import warnings
warnings.filterwarnings('ignore')

# %%
print(tf.__version__)
# Out:
# 2.12.0

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## Load data

# %%
train_df = pd.read_csv(
    '/gdrive/MyDrive/TrafficFlowData/metro_interstate_traffic_volume_train.csv', 
    index_col=0)
val_df = pd.read_csv(
    '/gdrive/MyDrive/TrafficFlowData/metro_interstate_traffic_volume_validate.csv', 
    index_col=0)
test_df = pd.read_csv(
    '/gdrive/MyDrive/TrafficFlowData/metro_interstate_traffic_volume_test.csv', 
    index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
# set images-folder filepath
images_dir = '/gdrive/My Drive/TrafficFlowImages'

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False

# %% [markdown]
# # Helper Functions

# %%
class DataWindow():
  # Initialise a DataWindow object
  def __init__(self, input_width, label_width, shift, train_df=train_df, 
             val_df=val_df, test_df=test_df, label_columns=None):
    self.train_df = train_df
    self.val_df = val_df
    self.test_df = test_df
    
    # Name of column to predict
    self.label_columns = label_columns
    if label_columns is not None:
      # Dict. of name and index of label column. Used for plotting.
      self.label_columns_indices = {name: i for i, name in 
                                    enumerate(label_columns)}
    # Dict. of name and index of each column. Used for plotting.
    # Used to seperate the features from target variable
    self.column_indices = {name: i for i, name in 
                                    enumerate(train_df.columns)}
    self.input_width = input_width
    self.label_width = label_width
    self.shift = shift

    self.total_window_size = input_width + shift
    # Returns a slice object that specifies how to slice a sequence.
    # In this case, it says that hte input slice starts at 0, ends when 
    # input_width is reached
    self.input_slice = slice(0, input_width)
      
    # Assign indices to the inputs. These are usefull for plotting.
    self.input_indices = np.arange(self.total_window_size)[self.input_slice]
      
    # Get the index at which the label starts. In this case, it's the total 
    # window size less the width of the label.
    self.label_start = self.total_window_size - self.label_width
    # Repeat steps applied for input for labels
    self.labels_slice = slice(self.label_start, None)
    self.label_indices = np.arange(self.total_window_size)[self.labels_slice]
  
  # Seperate the big data window into two windows: one for inputs, 
  # the other for the lables
  def split_to_inputs_labels(self, features):
    inputs = features[:, self.input_slice, :]
    labels = features[:, self.labels_slice, :]
    if self.label_columns is not None:
      labels = tf.stack(
          [labels[:, :, self.column_indices[name]] for name in self.label_columns], 
          axis=-1
      )
    inputs.set_shape([None, self.input_width, None])
    labels.set_shape([None, self.label_width, None])

    return inputs, labels

  # Plot sample of data windows
  def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
    inputs, labels = self.sample_batch

    plt.figure(figsize=(12, 8))
    plot_col_index = self.column_indices[plot_col]
    max_n = min(max_subplots, len(inputs))

    for n in range(max_n):
      plt.subplot(3, 1, n+1)
      plt.ylabel(f'{plot_col} [scaled]')
      plt.plot(self.input_indices, inputs[n, :, plot_col_index], 
               label='Inputs', marker='.', zorder=-10)
      
      if self.label_columns:
        label_col_index = self.label_columns_indices.get(plot_col, None)
      else:
        label_col_index = plot_col_index

      if label_col_index is None:
        continue  
      
      plt.scatter(self.label_indices, labels[n, :, label_col_index], 
                  edgecolors='k', marker='s', label='Labels', c='green', s=64)
      
      if model is not None:
        predictions = model(inputs)
        plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                    marker='X', edgecolors='k', label='Predictions', c='red', 
                    s=64)
      
      if n == 0:
        plt.legend()
    
    plt.xlabel('Time (h)')
  
  # Format dataset into tensors, fed to dl model.
  def make_dataset(self, data):
    data = np.array(data, dtype=np.float32)
    # Use tensor timeseries_dataset_from_array function to create a dataset of 
    # sliding windows.
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data = data,
        # targets are handled by the split_to_input_labels function, 
        # thus set to none.
        targets = None,
        sequence_length = self.total_window_size,
        # Number of timesteps seperating each sequence.
        # In this case sequences are consecutive hence sequence_stride equall 1
        sequence_stride = 1,
        # Shuffle the batch sequence, not the window/sequence timesteps
        shuffle = True,
        # Sequences in a batch
        batch_size=32
    )

    ds = ds.map(self.split_to_inputs_labels)
    return ds

  @property
  def train(self):
    return self.make_dataset(self.train_df)
    
  @property
  def val(self):
    return self.make_dataset(self.val_df)
    
  @property
  def test(self):
    return self.make_dataset(self.test_df)
    
  @property
  def sample_batch(self):
    result = getattr(self, '_sample_batch', None)
    if result is None:
      result = next(iter(self.train))
      self._sample_batch = result
    return result

# %%
# DEF: Configure deep learning model and fit data.
# patience: number of epochs after which model stops training-
# granted the validation loss does not improve.
# max_epochs: maximum number of epochs to train the model. Method stops when 3- 
# consecutive epochs do not decrease the validation loss.
def compile_and_fit(model, window, patience=3, max_epochs=50):
  early_stopping = EarlyStopping(monitor='val_loss', 
                                 patience=patience, 
                                 mode='min')
  
  model.compile(loss=MeanSquaredError(), # Use MSE as loss function.
                # Adam's an optimiser proivding a method that descends the 
                # gradient applied to the weights of the layers.
                # Use MAE as error metric
                optimizer=Adam(),
                metrics=[MeanAbsoluteError()]) 
  
  history = model.fit(window.train, # Fit model on training set
                      epochs=max_epochs, 
                      validation_data=window.val, # Use validation set to calc validation loss
                      callbacks=[early_stopping]) # Pass early_stopping as a calllback
  
  return history

# %% [markdown]
# # Long Short-Term Memory (LSTM) Model
# An LSTM uses past information with new information to make predictions, additionally resolving the conventional RNN's short-term memory loss caused by a vanishing gradient. Small gradients bring about insignificant to no changes in the weight, resulting in weights un-updated that terminates network learning. (As an aside, weights are assigned to each feature to mark their contribution in predicting the target.)

# %% [markdown]
# ## Single Step Model

# %%
wide_window= DataWindow(input_width=24, label_width=24, shift=1, 
                        label_columns=['traffic_volume'])

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True), Dense(units=1)
    ])

history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 17s 22ms/step - loss: 0.0240 - mean_absolute_error: 0.1110 - val_loss: 0.0095 - val_mean_absolute_error: 0.0729
# Epoch 2/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0066 - mean_absolute_error: 0.0586 - val_loss: 0.0046 - val_mean_absolute_error: 0.0498
# Epoch 3/50
# 384/384 [==============================] - 8s 19ms/step - loss: 0.0045 - mean_absolute_error: 0.0483 - val_loss: 0.0036 - val_mean_absolute_error: 0.0435
# Epoch 4/50
# 384/384 [==============================] - 7s 18ms/step - loss: 0.0039 - mean_absolute_error: 0.0442 - val_loss: 0.0033 - val_mean_absolute_error: 0.0414
# Epoch 5/50
# 384/384 [==============================] - 8s 22ms/step - loss: 0.0036 - mean_absolute_error: 0.0415 - val_loss: 0.0030 - val_mean_absolute_error: 0.0382
# Epoch 6/50
# 384/384 [==============================] - 7s 18ms/step - loss: 0.0032 - mean_absolute_error: 0.0390 - val_loss: 0.0026 - val_mean_absolute_error: 0.0357
# Epoch 7/50
# 384/384 [==============================] - 7s 18ms/step - loss: 0.0029 - mean_absolute_error: 0.0368 - val_loss: 0.0025 - val_mean_absolute_error: 0.0342
# Epoch 8/50
# 384/384 [==============================] - 14s 37ms/step - loss: 0.0028 - mean_absolute_error: 0.0358 - val_loss: 0.0023 - val_mean_absolute_error: 0.0330
# Epoch 9/50
# 384/384 [==============================] - 13s 34ms/step - loss: 0.0027 - mean_absolute_error: 0.0349 - val_loss: 0.0023 - val_mean_absolute_error: 0.0332
# Epoch 10/50
# 384/384 [==============================] - 12s 32ms/step - loss: 0.0026 - mean_absolute_error: 0.0341 - val_loss: 0.0022 - val_mean_absolute_error: 0.0319
# Epoch 11/50
# 384/384 [==============================] - 10s 26ms/step - loss: 0.0025 - mean_absolute_error: 0.0336 - val_loss: 0.0022 - val_mean_absolute_error: 0.0321
# Epoch 12/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0024 - mean_absolute_error: 0.0331 - val_loss: 0.0020 - val_mean_absolute_error: 0.0315
# Epoch 13/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0024 - mean_absolute_error: 0.0324 - val_loss: 0.0019 - val_mean_absolute_error: 0.0298
# Epoch 14/50
# 384/384 [==============================] - 10s 25ms/step - loss: 0.0023 - mean_absolute_error: 0.0319 - val_loss: 0.0020 - val_mean_absolute_error: 0.0308
# Epoch 15/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0022 - mean_absolute_error: 0.0315 - val_loss: 0.0019 - val_mean_absolute_error: 0.0291
# Epoch 16/50
# 384/384 [==============================] - 10s 26ms/step - loss: 0.0022 - mean_absolute_error: 0.0312 - val_loss: 0.0019 - val_mean_absolute_error: 0.0296
# Epoch 17/50
# 384/384 [==============================] - 10s 27ms/step - loss: 0.0022 - mean_absolute_error: 0.0309 - val_loss: 0.0018 - val_mean_absolute_error: 0.0286
# Epoch 18/50
# 384/384 [==============================] - 11s 29ms/step - loss: 0.0021 - mean_absolute_error: 0.0305 - val_loss: 0.0017 - val_mean_absolute_error: 0.0280
# Epoch 19/50
# 384/384 [==============================] - 10s 26ms/step - loss: 0.0021 - mean_absolute_error: 0.0304 - val_loss: 0.0017 - val_mean_absolute_error: 0.0284
# Epoch 20/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0017 - val_mean_absolute_error: 0.0285
# Epoch 21/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0020 - mean_absolute_error: 0.0298 - val_loss: 0.0017 - val_mean_absolute_error: 0.0277
# Epoch 22/50
# 384/384 [==============================] - 8s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0017 - val_mean_absolute_error: 0.0280
# Epoch 23/50
# 384/384 [==============================] - 7s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0294 - val_loss: 0.0016 - val_mean_absolute_error: 0.0272
# Epoch 24/50
# 384/384 [==============================] - 10s 26ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0016 - val_mean_absolute_error: 0.0266
# Epoch 25/50
# 384/384 [==============================] - 11s 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0292 - val_loss: 0.0016 - val_mean_absolute_error: 0.0276
# Epoch 26/50
# 384/384 [==============================] - 12s 32ms/step - loss: 0.0019 - mean_absolute_error: 0.0290 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 27/50
# 384/384 [==============================] - 13s 32ms/step - loss: 0.0019 - mean_absolute_error: 0.0289 - val_loss: 0.0016 - val_mean_absolute_error: 0.0280
# Epoch 28/50
# 384/384 [==============================] - 10s 27ms/step - loss: 0.0019 - mean_absolute_error: 0.0287 - val_loss: 0.0018 - val_mean_absolute_error: 0.0311
# Epoch 29/50
# 384/384 [==============================] - 11s 29ms/step - loss: 0.0019 - mean_absolute_error: 0.0287 - val_loss: 0.0016 - val_mean_absolute_error: 0.0284
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0284

# %% [markdown]
# ### Plot

# %%
wide_window.plot(lstm_model)

# %% [markdown]
# ### Compare Single-Step Models

# %%
# MAE's of Single-Step Models from traffic_flow_forecasting_part_1.ipynb
mae_val = [0.083, 0.066, 0.032]
mae_test = [0.081, 0.063, 0.031]

# Add LSTM model results to the above arrays 
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_single_step_models', dpi=300)

# %% [markdown]
# ## Multi-Step Model

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, 
                          label_columns=['traffic_volume'])

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True), 
    Dense(1, kernel_initializer=tf.initializers.zeros)
    ])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 17s 29ms/step - loss: 0.0429 - mean_absolute_error: 0.1456 - val_loss: 0.0200 - val_mean_absolute_error: 0.1002
# Epoch 2/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0161 - mean_absolute_error: 0.0873 - val_loss: 0.0170 - val_mean_absolute_error: 0.0892
# Epoch 3/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0145 - mean_absolute_error: 0.0809 - val_loss: 0.0160 - val_mean_absolute_error: 0.0840
# Epoch 4/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0139 - mean_absolute_error: 0.0782 - val_loss: 0.0157 - val_mean_absolute_error: 0.0803
# Epoch 5/50
# 383/383 [==============================] - 7s 17ms/step - loss: 0.0136 - mean_absolute_error: 0.0770 - val_loss: 0.0153 - val_mean_absolute_error: 0.0824
# Epoch 6/50
# 383/383 [==============================] - 7s 19ms/step - loss: 0.0133 - mean_absolute_error: 0.0759 - val_loss: 0.0150 - val_mean_absolute_error: 0.0810
# Epoch 7/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0130 - mean_absolute_error: 0.0748 - val_loss: 0.0146 - val_mean_absolute_error: 0.0810
# Epoch 8/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0129 - mean_absolute_error: 0.0742 - val_loss: 0.0143 - val_mean_absolute_error: 0.0778
# Epoch 9/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0127 - mean_absolute_error: 0.0736 - val_loss: 0.0147 - val_mean_absolute_error: 0.0785
# Epoch 10/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0126 - mean_absolute_error: 0.0730 - val_loss: 0.0139 - val_mean_absolute_error: 0.0761
# Epoch 11/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0124 - mean_absolute_error: 0.0724 - val_loss: 0.0141 - val_mean_absolute_error: 0.0764
# Epoch 12/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0123 - mean_absolute_error: 0.0719 - val_loss: 0.0139 - val_mean_absolute_error: 0.0773
# Epoch 13/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0123 - mean_absolute_error: 0.0716 - val_loss: 0.0139 - val_mean_absolute_error: 0.0773
# Epoch 14/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0122 - mean_absolute_error: 0.0713 - val_loss: 0.0136 - val_mean_absolute_error: 0.0758
# Epoch 15/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0121 - mean_absolute_error: 0.0708 - val_loss: 0.0137 - val_mean_absolute_error: 0.0755
# Epoch 16/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0119 - mean_absolute_error: 0.0701 - val_loss: 0.0145 - val_mean_absolute_error: 0.0795
# Epoch 17/50
# 383/383 [==============================] - 7s 17ms/step - loss: 0.0118 - mean_absolute_error: 0.0699 - val_loss: 0.0133 - val_mean_absolute_error: 0.0730
# Epoch 18/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0116 - mean_absolute_error: 0.0693 - val_loss: 0.0143 - val_mean_absolute_error: 0.0802
# Epoch 19/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0115 - mean_absolute_error: 0.0688 - val_loss: 0.0132 - val_mean_absolute_error: 0.0758
# Epoch 20/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0113 - mean_absolute_error: 0.0684 - val_loss: 0.0128 - val_mean_absolute_error: 0.0735
# Epoch 21/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0111 - mean_absolute_error: 0.0677 - val_loss: 0.0126 - val_mean_absolute_error: 0.0731
# Epoch 22/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0110 - mean_absolute_error: 0.0672 - val_loss: 0.0131 - val_mean_absolute_error: 0.0706
# Epoch 23/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0109 - mean_absolute_error: 0.0668 - val_loss: 0.0121 - val_mean_absolute_error: 0.0716
# Epoch 24/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0107 - mean_absolute_error: 0.0664 - val_loss: 0.0124 - val_mean_absolute_error: 0.0682
# Epoch 25/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0107 - mean_absolute_error: 0.0660 - val_loss: 0.0120 - val_mean_absolute_error: 0.0702
# Epoch 26/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0105 - mean_absolute_error: 0.0653 - val_loss: 0.0119 - val_mean_absolute_error: 0.0684
# Epoch 27/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0104 - mean_absolute_error: 0.0647 - val_loss: 0.0120 - val_mean_absolute_error: 0.0708
# Epoch 28/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0103 - mean_absolute_error: 0.0646 - val_loss: 0.0118 - val_mean_absolute_error: 0.0682
# Epoch 29/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0103 - mean_absolute_error: 0.0644 - val_loss: 0.0119 - val_mean_absolute_error: 0.0674
# Epoch 30/50
# 383/383 [==============================] - 12s 32ms/step - loss: 0.0101 - mean_absolute_error: 0.0635 - val_loss: 0.0117 - val_mean_absolute_error: 0.0677
# Epoch 31/50
# 383/383 [==============================] - 8s 19ms/step - loss: 0.0100 - mean_absolute_error: 0.0633 - val_loss: 0.0112 - val_mean_absolute_error: 0.0657
# Epoch 32/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0100 - mean_absolute_error: 0.0632 - val_loss: 0.0116 - val_mean_absolute_error: 0.0713
# Epoch 33/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0099 - mean_absolute_error: 0.0630 - val_loss: 0.0117 - val_mean_absolute_error: 0.0710
# Epoch 34/50
# 383/383 [==============================] - 12s 31ms/step - loss: 0.0099 - mean_absolute_error: 0.0627 - val_loss: 0.0111 - val_mean_absolute_error: 0.0662
# Epoch 35/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0098 - mean_absolute_error: 0.0624 - val_loss: 0.0112 - val_mean_absolute_error: 0.0647
# Epoch 36/50
# 383/383 [==============================] - 10s 25ms/step - loss: 0.0098 - mean_absolute_error: 0.0625 - val_loss: 0.0111 - val_mean_absolute_error: 0.0688
# Epoch 37/50
# 383/383 [==============================] - 11s 29ms/step - loss: 0.0098 - mean_absolute_error: 0.0624 - val_loss: 0.0109 - val_mean_absolute_error: 0.0648
# Epoch 38/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0097 - mean_absolute_error: 0.0619 - val_loss: 0.0109 - val_mean_absolute_error: 0.0655
# Epoch 39/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0096 - mean_absolute_error: 0.0616 - val_loss: 0.0108 - val_mean_absolute_error: 0.0657
# Epoch 40/50
# 383/383 [==============================] - 12s 31ms/step - loss: 0.0096 - mean_absolute_error: 0.0614 - val_loss: 0.0109 - val_mean_absolute_error: 0.0634
# Epoch 41/50
# 383/383 [==============================] - 13s 35ms/step - loss: 0.0095 - mean_absolute_error: 0.0611 - val_loss: 0.0108 - val_mean_absolute_error: 0.0658
# Epoch 42/50
# 383/383 [==============================] - 10s 27ms/step - loss: 0.0096 - mean_absolute_error: 0.0613 - val_loss: 0.0109 - val_mean_absolute_error: 0.0637
# Epoch 43/50
# 383/383 [==============================] - 12s 32ms/step - loss: 0.0094 - mean_absolute_error: 0.0608 - val_loss: 0.0110 - val_mean_absolute_error: 0.0629
# Epoch 44/50
# 383/383 [==============================] - 13s 33ms/step - loss: 0.0093 - mean_absolute_error: 0.0606 - val_loss: 0.0108 - val_mean_absolute_error: 0.0631
# Epoch 45/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0093 - mean_absolute_error: 0.0605 - val_loss: 0.0115 - val_mean_absolute_error: 0.0639
# Epoch 46/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0093 - mean_absolute_error: 0.0603 - val_loss: 0.0105 - val_mean_absolute_error: 0.0651
# Epoch 47/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0092 - mean_absolute_error: 0.0601 - val_loss: 0.0106 - val_mean_absolute_error: 0.0655
# Epoch 48/50
# 383/383 [==============================] - 12s 32ms/step - loss: 0.0092 - mean_absolute_error: 0.0601 - val_loss: 0.0108 - val_mean_absolute_error: 0.0625
# Epoch 49/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0092 - mean_absolute_error: 0.0602 - val_loss: 0.0108 - val_mean_absolute_error: 0.0626
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0108 - mean_absolute_error: 0.0626

# %% [markdown]
# ### Plot

# %%
multi_window.plot(ms_lstm_model)

# %% [markdown]
# ### Compare Multi-Step Models

# %%
# MAE's of Multi-Step Models from traffic_flow_forecasting_part_1.ipynb
ms_mae_val = [0.352, 0.353, 0.089, 0.072]
ms_mae_test = [0.347, 0.344, 0.077, 0.061]

# Add LSTM model results to the above arrays 
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(ms_mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_multi_step_models', dpi=300)

# %% [markdown]
# ## Multi-output Model

# %%
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, 
                            label_columns=['temp', 'traffic_volume'])

# %%
mo_lstm_model = Sequential([LSTM(32, return_sequences=True), Dense(units = 2)])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 18s 33ms/step - loss: 0.0246 - mean_absolute_error: 0.1027 - val_loss: 0.0088 - val_mean_absolute_error: 0.0603
# Epoch 2/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0057 - mean_absolute_error: 0.0487 - val_loss: 0.0041 - val_mean_absolute_error: 0.0415
# Epoch 3/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0036 - mean_absolute_error: 0.0384 - val_loss: 0.0029 - val_mean_absolute_error: 0.0354
# Epoch 4/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0030 - mean_absolute_error: 0.0347 - val_loss: 0.0024 - val_mean_absolute_error: 0.0330
# Epoch 5/50
# 384/384 [==============================] - 8s 22ms/step - loss: 0.0026 - mean_absolute_error: 0.0319 - val_loss: 0.0020 - val_mean_absolute_error: 0.0290
# Epoch 6/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0022 - mean_absolute_error: 0.0291 - val_loss: 0.0018 - val_mean_absolute_error: 0.0277
# Epoch 7/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0020 - mean_absolute_error: 0.0275 - val_loss: 0.0016 - val_mean_absolute_error: 0.0263
# Epoch 8/50
# 384/384 [==============================] - 13s 32ms/step - loss: 0.0019 - mean_absolute_error: 0.0261 - val_loss: 0.0015 - val_mean_absolute_error: 0.0244
# Epoch 9/50
# 384/384 [==============================] - 11s 28ms/step - loss: 0.0018 - mean_absolute_error: 0.0252 - val_loss: 0.0014 - val_mean_absolute_error: 0.0239
# Epoch 10/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0017 - mean_absolute_error: 0.0245 - val_loss: 0.0013 - val_mean_absolute_error: 0.0228
# Epoch 11/50
# 384/384 [==============================] - 10s 25ms/step - loss: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 0.0013 - val_mean_absolute_error: 0.0228
# Epoch 12/50
# 384/384 [==============================] - 7s 18ms/step - loss: 0.0016 - mean_absolute_error: 0.0234 - val_loss: 0.0012 - val_mean_absolute_error: 0.0217
# Epoch 13/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0016 - mean_absolute_error: 0.0231 - val_loss: 0.0012 - val_mean_absolute_error: 0.0215
# Epoch 14/50
# 384/384 [==============================] - 11s 28ms/step - loss: 0.0015 - mean_absolute_error: 0.0228 - val_loss: 0.0012 - val_mean_absolute_error: 0.0217
# Epoch 15/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0015 - mean_absolute_error: 0.0224 - val_loss: 0.0012 - val_mean_absolute_error: 0.0214
# Epoch 16/50
# 384/384 [==============================] - 11s 28ms/step - loss: 0.0015 - mean_absolute_error: 0.0223 - val_loss: 0.0012 - val_mean_absolute_error: 0.0215
# Epoch 17/50
# 384/384 [==============================] - 11s 29ms/step - loss: 0.0014 - mean_absolute_error: 0.0220 - val_loss: 0.0011 - val_mean_absolute_error: 0.0214
# Epoch 18/50
# 384/384 [==============================] - 10s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0218 - val_loss: 0.0011 - val_mean_absolute_error: 0.0211
# Epoch 19/50
# 384/384 [==============================] - 8s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 20/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0206
# Epoch 21/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0215 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# Epoch 22/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0013 - mean_absolute_error: 0.0213 - val_loss: 0.0010 - val_mean_absolute_error: 0.0197
# Epoch 23/50
# 384/384 [==============================] - 10s 25ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0195
# Epoch 24/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0211 - val_loss: 9.8760e-04 - val_mean_absolute_error: 0.0194
# Epoch 25/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0202
# Epoch 26/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 9.9687e-04 - val_mean_absolute_error: 0.0198
# Epoch 27/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 0.0010 - val_mean_absolute_error: 0.0201
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0201

# %% [markdown]
# ### Plot

# %% [markdown]
# #### Traffic Volume

# %%
mo_wide_window.plot(mo_lstm_model)

# %% [markdown]
# #### Temperature

# %%
mo_wide_window.plot(model=mo_lstm_model, plot_col='temp')

# %% [markdown]
# ### Compare Multi-Output Models

# %%
# MAE's of Multi-Step Models from traffic_flow_forecasting_part_1.ipynb
mo_mae_val = [0.048, 0.038, 0.027]
mo_mae_test = [0.047, 0.036, 0.026]

# Add LSTM model results to the above arrays 
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(mo_mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_multi_output_models', dpi=300)

# %% [markdown]
# # Convolutional Neural Networks (CNN)

# %% [markdown]
# ## Single-Step Model

# %%
KERNEL_WIDTH = 3

conv_window = DataWindow(input_width=KERNEL_WIDTH, label_width=1, shift=1, 
                         label_columns=['traffic_volume'])

LABEL_WIDTH = 24
INPUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

wide_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, 
                              shift=1, label_columns=['traffic_volume'])
# filters: number of neurons in convolutional layer
cnn_model = Sequential([Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), 
                               activation='relu'),
                        Dense(units=32, activation='relu'), Dense(units=1)
                        ])

history = compile_and_fit(cnn_model, conv_window)

val_performance['CNN'] = cnn_model.evaluate(conv_window.val)
performance['CNN'] = cnn_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 6s 8ms/step - loss: 0.0203 - mean_absolute_error: 0.0917 - val_loss: 0.0055 - val_mean_absolute_error: 0.0541
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0048 - mean_absolute_error: 0.0509 - val_loss: 0.0038 - val_mean_absolute_error: 0.0468
# Epoch 3/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0037 - mean_absolute_error: 0.0446 - val_loss: 0.0028 - val_mean_absolute_error: 0.0390
# Epoch 4/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0413 - val_loss: 0.0025 - val_mean_absolute_error: 0.0372
# Epoch 5/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0397 - val_loss: 0.0024 - val_mean_absolute_error: 0.0366
# Epoch 6/50
# 384/384 [==============================] - 4s 9ms/step - loss: 0.0027 - mean_absolute_error: 0.0373 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 7/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0361 - val_loss: 0.0024 - val_mean_absolute_error: 0.0373
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0354 - val_loss: 0.0020 - val_mean_absolute_error: 0.0323
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0353 - val_loss: 0.0026 - val_mean_absolute_error: 0.0393
# Epoch 10/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0342 - val_loss: 0.0018 - val_mean_absolute_error: 0.0304
# Epoch 11/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0339 - val_loss: 0.0017 - val_mean_absolute_error: 0.0298
# Epoch 12/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0336 - val_loss: 0.0020 - val_mean_absolute_error: 0.0334
# Epoch 13/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0337 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 14/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0336 - val_loss: 0.0018 - val_mean_absolute_error: 0.0296
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0296

# %%
# Add CNN model results to the mae arrays 
mae_val.append(val_performance['CNN'][1])
mae_test.append(performance['CNN'][1])

# %% [markdown]
# ### Plot

# %%
wide_conv_window.plot(cnn_model)

# %% [markdown]
# ## Mult-Step Model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

multi_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, 
                                 shift=24, label_columns=['traffic_volume'])

ms_cnn_model = Sequential([
    Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
    Dense(units=32, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_cnn_model, multi_window)

ms_val_performance = {}
ms_performance= {}

ms_val_performance['CNN'] = ms_cnn_model.evaluate(multi_window.val)
ms_performance['CNN'] = ms_cnn_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 5s 8ms/step - loss: 0.0334 - mean_absolute_error: 0.1221 - val_loss: 0.0165 - val_mean_absolute_error: 0.0834
# Epoch 2/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0141 - mean_absolute_error: 0.0785 - val_loss: 0.0156 - val_mean_absolute_error: 0.0811
# Epoch 3/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0137 - mean_absolute_error: 0.0778 - val_loss: 0.0149 - val_mean_absolute_error: 0.0814
# Epoch 4/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0133 - mean_absolute_error: 0.0769 - val_loss: 0.0146 - val_mean_absolute_error: 0.0788
# Epoch 5/50
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0131 - mean_absolute_error: 0.0765 - val_loss: 0.0145 - val_mean_absolute_error: 0.0796
# Epoch 6/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0129 - mean_absolute_error: 0.0759 - val_loss: 0.0145 - val_mean_absolute_error: 0.0758
# Epoch 7/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0128 - mean_absolute_error: 0.0754 - val_loss: 0.0143 - val_mean_absolute_error: 0.0773
# Epoch 8/50
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0127 - mean_absolute_error: 0.0753 - val_loss: 0.0143 - val_mean_absolute_error: 0.0760
# Epoch 9/50
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0127 - mean_absolute_error: 0.0752 - val_loss: 0.0143 - val_mean_absolute_error: 0.0832
# Epoch 10/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0125 - mean_absolute_error: 0.0744 - val_loss: 0.0146 - val_mean_absolute_error: 0.0852
# Epoch 11/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0124 - mean_absolute_error: 0.0741 - val_loss: 0.0138 - val_mean_absolute_error: 0.0754
# Epoch 12/50
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0124 - mean_absolute_error: 0.0740 - val_loss: 0.0140 - val_mean_absolute_error: 0.0822
# Epoch 13/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0736 - val_loss: 0.0137 - val_mean_absolute_error: 0.0754
# Epoch 14/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0737 - val_loss: 0.0137 - val_mean_absolute_error: 0.0752
# Epoch 15/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0122 - mean_absolute_error: 0.0730 - val_loss: 0.0139 - val_mean_absolute_error: 0.0740
# Epoch 16/50
# 383/383 [==============================] - 4s 11ms/step - loss: 0.0122 - mean_absolute_error: 0.0731 - val_loss: 0.0137 - val_mean_absolute_error: 0.0757
# Epoch 17/50
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0121 - mean_absolute_error: 0.0726 - val_loss: 0.0138 - val_mean_absolute_error: 0.0761
# Epoch 18/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0729 - val_loss: 0.0138 - val_mean_absolute_error: 0.0779
# Epoch 19/50
# 383/383 [==============================] - 3s 7ms/step - loss: 0.0121 - mean_absolute_error: 0.0724 - val_loss: 0.0138 - val_mean_absolute_error: 0.0775
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0138 - mean_absolute_error: 0.0775

# %%
# Add CNN model results to the ms_mae arrays
ms_mae_val.append(ms_val_performance['CNN'][1])
ms_mae_test.append(ms_performance['CNN'][1])

# %% [markdown]
# ### Plot

# %%
multi_window.plot(ms_cnn_model)

# %% [markdown]
# ## Multi-Output Model

# %%
KERNEL_WIDTH = 3
LABEL_WIDTH = 24
INUT_WIDTH = LABEL_WIDTH + KERNEL_WIDTH - 1

wide_mo_conv_window = DataWindow(input_width=INPUT_WIDTH, label_width=LABEL_WIDTH, 
                                 shift=1, label_columns=['temp', 'traffic_volume'])

mo_cnn_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_model, wide_mo_conv_window)

mo_val_performance = {}
mo_performance= {}

mo_val_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0286 - mean_absolute_error: 0.1001 - val_loss: 0.0039 - val_mean_absolute_error: 0.0403
# Epoch 2/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0032 - mean_absolute_error: 0.0369 - val_loss: 0.0024 - val_mean_absolute_error: 0.0325
# Epoch 3/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0023 - mean_absolute_error: 0.0313 - val_loss: 0.0018 - val_mean_absolute_error: 0.0288
# Epoch 4/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0020 - mean_absolute_error: 0.0285 - val_loss: 0.0015 - val_mean_absolute_error: 0.0259
# Epoch 5/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0262 - val_loss: 0.0013 - val_mean_absolute_error: 0.0240
# Epoch 6/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0244 - val_loss: 0.0011 - val_mean_absolute_error: 0.0223
# Epoch 7/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0014 - mean_absolute_error: 0.0232 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 8/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 0.0010 - val_mean_absolute_error: 0.0211
# Epoch 9/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 0.0010 - val_mean_absolute_error: 0.0209
# Epoch 10/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 9.5943e-04 - val_mean_absolute_error: 0.0205
# Epoch 11/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0211 - val_loss: 9.6023e-04 - val_mean_absolute_error: 0.0202
# Epoch 12/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0208 - val_loss: 9.4362e-04 - val_mean_absolute_error: 0.0199
# Epoch 13/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 0.0010 - val_mean_absolute_error: 0.0213
# Epoch 14/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 8.7913e-04 - val_mean_absolute_error: 0.0189
# Epoch 15/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0012 - mean_absolute_error: 0.0201 - val_loss: 8.8050e-04 - val_mean_absolute_error: 0.0191
# Epoch 16/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 8.7434e-04 - val_mean_absolute_error: 0.0194
# Epoch 17/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0199 - val_loss: 9.2005e-04 - val_mean_absolute_error: 0.0204
# Epoch 18/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0197 - val_loss: 9.3351e-04 - val_mean_absolute_error: 0.0210
# Epoch 19/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0195 - val_loss: 8.7673e-04 - val_mean_absolute_error: 0.0194
# 109/109 [==============================] - 0s 4ms/step - loss: 8.7673e-04 - mean_absolute_error: 0.0194

# %%
# Add CNN model results to the mo_mae arrays 
mo_mae_val.append(mo_val_performance['CNN'][1])
mo_mae_test.append(mo_performance['CNN'][1])

# %% [markdown]
# ### Plot

# %% [markdown]
# #### Traffic Volume

# %%
wide_mo_conv_window.plot(mo_cnn_model)

# %% [markdown]
# #### Temperature

# %%
wide_mo_conv_window.plot(model=mo_cnn_model, plot_col='temp')

# %% [markdown]
# # CNN & LSTM Model Combined

# %% [markdown]
# ## Single-Step Model

# %%
KERNEL_WIDTH = 3

cnn_lstm_model = Sequential([
    Conv1D(filters=32,
           kernel_size=(KERNEL_WIDTH,),
           activation='relu'),
    LSTM(32, return_sequences=True),
    LSTM(32, return_sequences=True),
    Dense(1)
])

history = compile_and_fit(cnn_lstm_model, conv_window)

val_performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.val)
performance['CNN + LSTM'] = cnn_lstm_model.evaluate(conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 11s 13ms/step - loss: 0.0304 - mean_absolute_error: 0.1169 - val_loss: 0.0065 - val_mean_absolute_error: 0.0612
# Epoch 2/50
# 384/384 [==============================] - 4s 11ms/step - loss: 0.0058 - mean_absolute_error: 0.0554 - val_loss: 0.0052 - val_mean_absolute_error: 0.0570
# Epoch 3/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0047 - mean_absolute_error: 0.0499 - val_loss: 0.0038 - val_mean_absolute_error: 0.0467
# Epoch 4/50
# 384/384 [==============================] - 5s 12ms/step - loss: 0.0040 - mean_absolute_error: 0.0458 - val_loss: 0.0041 - val_mean_absolute_error: 0.0473
# Epoch 5/50
# 384/384 [==============================] - 4s 9ms/step - loss: 0.0036 - mean_absolute_error: 0.0435 - val_loss: 0.0026 - val_mean_absolute_error: 0.0376
# Epoch 6/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0031 - mean_absolute_error: 0.0403 - val_loss: 0.0026 - val_mean_absolute_error: 0.0367
# Epoch 7/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0030 - mean_absolute_error: 0.0394 - val_loss: 0.0027 - val_mean_absolute_error: 0.0374
# Epoch 8/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0028 - mean_absolute_error: 0.0374 - val_loss: 0.0021 - val_mean_absolute_error: 0.0333
# Epoch 9/50
# 384/384 [==============================] - 4s 11ms/step - loss: 0.0028 - mean_absolute_error: 0.0373 - val_loss: 0.0021 - val_mean_absolute_error: 0.0327
# Epoch 10/50
# 384/384 [==============================] - 4s 11ms/step - loss: 0.0027 - mean_absolute_error: 0.0370 - val_loss: 0.0023 - val_mean_absolute_error: 0.0347
# Epoch 11/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0027 - mean_absolute_error: 0.0366 - val_loss: 0.0020 - val_mean_absolute_error: 0.0324
# Epoch 12/50
# 384/384 [==============================] - 4s 12ms/step - loss: 0.0025 - mean_absolute_error: 0.0353 - val_loss: 0.0021 - val_mean_absolute_error: 0.0335
# Epoch 13/50
# 384/384 [==============================] - 4s 11ms/step - loss: 0.0025 - mean_absolute_error: 0.0349 - val_loss: 0.0020 - val_mean_absolute_error: 0.0319
# Epoch 14/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0025 - mean_absolute_error: 0.0349 - val_loss: 0.0021 - val_mean_absolute_error: 0.0341
# Epoch 15/50
# 384/384 [==============================] - 3s 9ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 16/50
# 384/384 [==============================] - 4s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0344 - val_loss: 0.0018 - val_mean_absolute_error: 0.0305
# Epoch 17/50
# 384/384 [==============================] - 4s 9ms/step - loss: 0.0023 - mean_absolute_error: 0.0336 - val_loss: 0.0021 - val_mean_absolute_error: 0.0338
# Epoch 18/50
# 384/384 [==============================] - 4s 9ms/step - loss: 0.0023 - mean_absolute_error: 0.0335 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
# Epoch 19/50
# 384/384 [==============================] - 4s 11ms/step - loss: 0.0023 - mean_absolute_error: 0.0336 - val_loss: 0.0018 - val_mean_absolute_error: 0.0300
# Epoch 20/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0331 - val_loss: 0.0019 - val_mean_absolute_error: 0.0308
# Epoch 21/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0022 - mean_absolute_error: 0.0326 - val_loss: 0.0018 - val_mean_absolute_error: 0.0296
# Epoch 22/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0324 - val_loss: 0.0019 - val_mean_absolute_error: 0.0312
# Epoch 23/50
# 384/384 [==============================] - 4s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0327 - val_loss: 0.0018 - val_mean_absolute_error: 0.0303
# Epoch 24/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0021 - mean_absolute_error: 0.0317 - val_loss: 0.0018 - val_mean_absolute_error: 0.0310
# 110/110 [==============================] - 1s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0310

# %% [markdown]
# ### Plot

# %%
wide_conv_window.plot(cnn_lstm_model)

# %% [markdown]
# ### Compare Single-Step Models

# %%
# Add combined CNN+LSTM model results to the mae arrays 
mae_val.append(val_performance['CNN + LSTM'][1])
mae_test.append(performance['CNN + LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_single_step_models', dpi=300)

# %% [markdown]
# ## Multi-Step Model

# %%
ms_cnn_lstm_model = Sequential([
   Conv1D(32, activation='relu', kernel_size=(KERNEL_WIDTH)),
   LSTM(32, return_sequences=True),
   Dense(1, kernel_initializer=tf.initializers.zeros), 
])

history = compile_and_fit(ms_cnn_lstm_model, multi_window)

ms_val_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.val)
ms_performance['CNN + LSTM'] = ms_cnn_lstm_model.evaluate(multi_window.test, 
                                                          verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 13s 26ms/step - loss: 0.0359 - mean_absolute_error: 0.1281 - val_loss: 0.0163 - val_mean_absolute_error: 0.0845
# Epoch 2/50
# 383/383 [==============================] - 7s 18ms/step - loss: 0.0140 - mean_absolute_error: 0.0790 - val_loss: 0.0154 - val_mean_absolute_error: 0.0813
# Epoch 3/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0133 - mean_absolute_error: 0.0761 - val_loss: 0.0145 - val_mean_absolute_error: 0.0778
# Epoch 4/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0127 - mean_absolute_error: 0.0742 - val_loss: 0.0142 - val_mean_absolute_error: 0.0776
# Epoch 5/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0124 - mean_absolute_error: 0.0729 - val_loss: 0.0137 - val_mean_absolute_error: 0.0776
# Epoch 6/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0121 - mean_absolute_error: 0.0717 - val_loss: 0.0135 - val_mean_absolute_error: 0.0754
# Epoch 7/50
# 383/383 [==============================] - 9s 25ms/step - loss: 0.0118 - mean_absolute_error: 0.0707 - val_loss: 0.0131 - val_mean_absolute_error: 0.0735
# Epoch 8/50
# 383/383 [==============================] - 7s 19ms/step - loss: 0.0116 - mean_absolute_error: 0.0697 - val_loss: 0.0131 - val_mean_absolute_error: 0.0723
# Epoch 9/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0112 - mean_absolute_error: 0.0682 - val_loss: 0.0125 - val_mean_absolute_error: 0.0710
# Epoch 10/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0110 - mean_absolute_error: 0.0675 - val_loss: 0.0124 - val_mean_absolute_error: 0.0683
# Epoch 11/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0106 - mean_absolute_error: 0.0660 - val_loss: 0.0118 - val_mean_absolute_error: 0.0713
# Epoch 12/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0105 - mean_absolute_error: 0.0659 - val_loss: 0.0117 - val_mean_absolute_error: 0.0710
# Epoch 13/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0102 - mean_absolute_error: 0.0646 - val_loss: 0.0115 - val_mean_absolute_error: 0.0692
# Epoch 14/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0101 - mean_absolute_error: 0.0641 - val_loss: 0.0114 - val_mean_absolute_error: 0.0689
# Epoch 15/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0099 - mean_absolute_error: 0.0634 - val_loss: 0.0112 - val_mean_absolute_error: 0.0678
# Epoch 16/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0099 - mean_absolute_error: 0.0629 - val_loss: 0.0109 - val_mean_absolute_error: 0.0664
# Epoch 17/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0097 - mean_absolute_error: 0.0624 - val_loss: 0.0114 - val_mean_absolute_error: 0.0699
# Epoch 18/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0097 - mean_absolute_error: 0.0623 - val_loss: 0.0107 - val_mean_absolute_error: 0.0665
# Epoch 19/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0096 - mean_absolute_error: 0.0619 - val_loss: 0.0107 - val_mean_absolute_error: 0.0633
# Epoch 20/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0094 - mean_absolute_error: 0.0611 - val_loss: 0.0109 - val_mean_absolute_error: 0.0633
# Epoch 21/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0093 - mean_absolute_error: 0.0608 - val_loss: 0.0106 - val_mean_absolute_error: 0.0641
# Epoch 22/50
# 383/383 [==============================] - 10s 25ms/step - loss: 0.0093 - mean_absolute_error: 0.0609 - val_loss: 0.0106 - val_mean_absolute_error: 0.0642
# Epoch 23/50
# 383/383 [==============================] - 8s 22ms/step - loss: 0.0092 - mean_absolute_error: 0.0605 - val_loss: 0.0107 - val_mean_absolute_error: 0.0639
# Epoch 24/50
# 383/383 [==============================] - 7s 19ms/step - loss: 0.0091 - mean_absolute_error: 0.0599 - val_loss: 0.0102 - val_mean_absolute_error: 0.0619
# Epoch 25/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0090 - mean_absolute_error: 0.0598 - val_loss: 0.0101 - val_mean_absolute_error: 0.0609
# Epoch 26/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0090 - mean_absolute_error: 0.0599 - val_loss: 0.0101 - val_mean_absolute_error: 0.0632
# Epoch 27/50
# 383/383 [==============================] - 8s 21ms/step - loss: 0.0088 - mean_absolute_error: 0.0588 - val_loss: 0.0100 - val_mean_absolute_error: 0.0592
# Epoch 28/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0087 - mean_absolute_error: 0.0586 - val_loss: 0.0100 - val_mean_absolute_error: 0.0613
# Epoch 29/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0087 - mean_absolute_error: 0.0587 - val_loss: 0.0098 - val_mean_absolute_error: 0.0602
# Epoch 30/50
# 383/383 [==============================] - 8s 20ms/step - loss: 0.0086 - mean_absolute_error: 0.0583 - val_loss: 0.0100 - val_mean_absolute_error: 0.0596
# Epoch 31/50
# 383/383 [==============================] - 10s 25ms/step - loss: 0.0086 - mean_absolute_error: 0.0582 - val_loss: 0.0099 - val_mean_absolute_error: 0.0596
# Epoch 32/50
# 383/383 [==============================] - 9s 22ms/step - loss: 0.0085 - mean_absolute_error: 0.0579 - val_loss: 0.0114 - val_mean_absolute_error: 0.0617
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0114 - mean_absolute_error: 0.0617

# %% [markdown]
# ### Plot

# %%
multi_window.plot(ms_cnn_lstm_model)

# %% [markdown]
# ### Compare Multi_Step Models

# %%
# Add CNN+LSTM model results to the ms_mae arrays
ms_mae_val.append(ms_val_performance['CNN + LSTM'][1])
ms_mae_test.append(ms_performance['CNN + LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(7)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(ms_mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_single_step_models', dpi=300)

# %% [markdown]
# ## Multi-Output Model

# %%
mo_cnn_lstm_model = Sequential([
    Conv1D(filters=32, kernel_size=(KERNEL_WIDTH,), activation='relu'),
    LSTM(32, return_sequences=True),
    Dense(units=2)
])

history = compile_and_fit(mo_cnn_lstm_model, wide_mo_conv_window)

mo_val_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.val)
mo_performance['CNN + LSTM'] = mo_cnn_model.evaluate(wide_mo_conv_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 13s 27ms/step - loss: 0.0151 - mean_absolute_error: 0.0751 - val_loss: 0.0031 - val_mean_absolute_error: 0.0377
# Epoch 2/50
# 384/384 [==============================] - 8s 20ms/step - loss: 0.0026 - mean_absolute_error: 0.0336 - val_loss: 0.0019 - val_mean_absolute_error: 0.0300
# Epoch 3/50
# 384/384 [==============================] - 9s 25ms/step - loss: 0.0020 - mean_absolute_error: 0.0292 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 4/50
# 384/384 [==============================] - 8s 22ms/step - loss: 0.0017 - mean_absolute_error: 0.0264 - val_loss: 0.0013 - val_mean_absolute_error: 0.0246
# Epoch 5/50
# 384/384 [==============================] - 7s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0247 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 6/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0015 - mean_absolute_error: 0.0238 - val_loss: 0.0011 - val_mean_absolute_error: 0.0222
# Epoch 7/50
# 384/384 [==============================] - 7s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0231 - val_loss: 0.0011 - val_mean_absolute_error: 0.0225
# Epoch 8/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0228 - val_loss: 0.0011 - val_mean_absolute_error: 0.0224
# Epoch 9/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0223 - val_loss: 0.0011 - val_mean_absolute_error: 0.0217
# Epoch 10/50
# 384/384 [==============================] - 8s 20ms/step - loss: 0.0013 - mean_absolute_error: 0.0218 - val_loss: 0.0011 - val_mean_absolute_error: 0.0216
# Epoch 11/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0013 - mean_absolute_error: 0.0217 - val_loss: 9.9352e-04 - val_mean_absolute_error: 0.0208
# Epoch 12/50
# 384/384 [==============================] - 10s 25ms/step - loss: 0.0013 - mean_absolute_error: 0.0213 - val_loss: 9.5465e-04 - val_mean_absolute_error: 0.0200
# Epoch 13/50
# 384/384 [==============================] - 8s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0210 - val_loss: 0.0010 - val_mean_absolute_error: 0.0214
# Epoch 14/50
# 384/384 [==============================] - 8s 22ms/step - loss: 0.0012 - mean_absolute_error: 0.0210 - val_loss: 0.0011 - val_mean_absolute_error: 0.0213
# Epoch 15/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.1217e-04 - val_mean_absolute_error: 0.0192
# Epoch 16/50
# 384/384 [==============================] - 9s 22ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 17/50
# 384/384 [==============================] - 8s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.3199e-04 - val_mean_absolute_error: 0.0207
# Epoch 18/50
# 384/384 [==============================] - 10s 26ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 9.0462e-04 - val_mean_absolute_error: 0.0196
# Epoch 19/50
# 384/384 [==============================] - 9s 23ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 9.2831e-04 - val_mean_absolute_error: 0.0194
# Epoch 20/50
# 384/384 [==============================] - 7s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - val_loss: 9.1488e-04 - val_mean_absolute_error: 0.0193
# Epoch 21/50
# 384/384 [==============================] - 9s 24ms/step - loss: 0.0011 - mean_absolute_error: 0.0199 - val_loss: 9.2339e-04 - val_mean_absolute_error: 0.0204
# 109/109 [==============================] - 0s 4ms/step - loss: 8.7673e-04 - mean_absolute_error: 0.0194

# %% [markdown]
# ### Plot

# %% [markdown]
# #### Traffic Flow

# %%
wide_mo_conv_window.plot(mo_cnn_lstm_model)

# %% [markdown]
# #### Temperature

# %%
wide_mo_conv_window.plot(model=mo_cnn_lstm_model, plot_col='temp')

# %% [markdown]
# ### Compare Multi-Output Models

# %%
# Add CNN+LSTM model results to mo_mae arrays 
mo_mae_val.append(mo_val_performance['CNN + LSTM'][1])
mo_mae_test.append(mo_performance['CNN + LSTM'][1])

# ---------------------------------------------------------------
x = np.arange(6)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM', 'CNN', 'CNN + LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
  plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(mo_mae_test):
  plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_multi_output_models', dpi=300)

# %% [markdown]
# # Auto-Regressive LSTM (ARLSTM)

# %%
muti_window = DataWindow(input_width=24, label_width=24, shift=24, 
                         label_columns=['traffic_volume'])

# %%
class AutoRegressive(Model):
    def __init__(self, units, out_steps):
        super().__init__()
        self.out_steps = out_steps
        self.units = units
        self.lstm_cell = LSTMCell(units)
        self.lstm_rnn = RNN(self.lstm_cell, return_state=True)
        self.dense = Dense(train_df.shape[1])
        
    def warmup(self, inputs):
        x, *state = self.lstm_rnn(inputs)
        prediction = self.dense(x)
                
        return prediction, state
    
    def call(self, inputs, training=None):
        predictions = []
        prediction, state = self.warmup(inputs)
        
        predictions.append(prediction)
        
        for n in range(1, self.out_steps):
            x = prediction
            x, state = self.lstm_cell(x, states=state, training=training)
            
            prediction = self.dense(x)
            predictions.append(prediction)
        
        predictions = tf.stack(predictions)
        predictions = tf.transpose(predictions, [1, 0, 2])
        
        return predictions

# %%
# Define data window
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# Initialise the AutoRegressive Model
ms_arlstm = AutoRegressive(units=32, out_steps=24)

# %%
history = compile_and_fit(ms_arlstm, multi_window)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 20s 32ms/step - loss: 0.0461 - mean_absolute_error: 0.1635 - val_loss: 0.0215 - val_mean_absolute_error: 0.1052
# Epoch 2/50
# 383/383 [==============================] - 13s 33ms/step - loss: 0.0168 - mean_absolute_error: 0.0925 - val_loss: 0.0166 - val_mean_absolute_error: 0.0872
# Epoch 3/50
# 383/383 [==============================] - 11s 28ms/step - loss: 0.0147 - mean_absolute_error: 0.0837 - val_loss: 0.0160 - val_mean_absolute_error: 0.0883
# Epoch 4/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0143 - mean_absolute_error: 0.0816 - val_loss: 0.0162 - val_mean_absolute_error: 0.0904
# Epoch 5/50
# 383/383 [==============================] - 10s 27ms/step - loss: 0.0138 - mean_absolute_error: 0.0795 - val_loss: 0.0149 - val_mean_absolute_error: 0.0813
# Epoch 6/50
# 383/383 [==============================] - 11s 28ms/step - loss: 0.0136 - mean_absolute_error: 0.0786 - val_loss: 0.0150 - val_mean_absolute_error: 0.0813
# Epoch 7/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0133 - mean_absolute_error: 0.0775 - val_loss: 0.0145 - val_mean_absolute_error: 0.0774
# Epoch 8/50
# 383/383 [==============================] - 11s 28ms/step - loss: 0.0133 - mean_absolute_error: 0.0773 - val_loss: 0.0155 - val_mean_absolute_error: 0.0864
# Epoch 9/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0128 - mean_absolute_error: 0.0756 - val_loss: 0.0153 - val_mean_absolute_error: 0.0760
# Epoch 10/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0126 - mean_absolute_error: 0.0748 - val_loss: 0.0139 - val_mean_absolute_error: 0.0742
# Epoch 11/50
# 383/383 [==============================] - 11s 28ms/step - loss: 0.0120 - mean_absolute_error: 0.0726 - val_loss: 0.0147 - val_mean_absolute_error: 0.0752
# Epoch 12/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0112 - mean_absolute_error: 0.0700 - val_loss: 0.0119 - val_mean_absolute_error: 0.0700
# Epoch 13/50
# 383/383 [==============================] - 11s 29ms/step - loss: 0.0105 - mean_absolute_error: 0.0674 - val_loss: 0.0117 - val_mean_absolute_error: 0.0658
# Epoch 14/50
# 383/383 [==============================] - 11s 29ms/step - loss: 0.0101 - mean_absolute_error: 0.0656 - val_loss: 0.0110 - val_mean_absolute_error: 0.0662
# Epoch 15/50
# 383/383 [==============================] - 9s 23ms/step - loss: 0.0096 - mean_absolute_error: 0.0638 - val_loss: 0.0116 - val_mean_absolute_error: 0.0655
# Epoch 16/50
# 383/383 [==============================] - 11s 27ms/step - loss: 0.0095 - mean_absolute_error: 0.0634 - val_loss: 0.0103 - val_mean_absolute_error: 0.0628
# Epoch 17/50
# 383/383 [==============================] - 10s 27ms/step - loss: 0.0092 - mean_absolute_error: 0.0624 - val_loss: 0.0104 - val_mean_absolute_error: 0.0617
# Epoch 18/50
# 383/383 [==============================] - 10s 26ms/step - loss: 0.0089 - mean_absolute_error: 0.0612 - val_loss: 0.0112 - val_mean_absolute_error: 0.0701
# Epoch 19/50
# 383/383 [==============================] - 9s 24ms/step - loss: 0.0090 - mean_absolute_error: 0.0613 - val_loss: 0.0109 - val_mean_absolute_error: 0.0671

# %%
ms_val_performance = {}
ms_performance = {}

ms_val_performance['ARLSTM'] = ms_arlstm.evaluate(multi_window.val)
ms_performance['ARLSTM'] = ms_arlstm.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 1s 9ms/step - loss: 0.0109 - mean_absolute_error: 0.0671

# %% [markdown]
# ### Plot

# %%
multi_window.plot(ms_arlstm)

# %% [markdown]
# ### Compare Multi-Step Models

# %%
# Add ARLSTM results to other model results array
ms_mae_val.append(ms_val_performance['ARLSTM'][1])
ms_mae_test.append(ms_performance['ARLSTM'][1])

# ---------------------------------------------------------------
x = np.arange(8)

labels = ['Baseline-Last', 'Baseline-Repeat', 'Linear', 
          'Dense', 'LSTM', 'CNN', 'CNN + LSTM', 'ARLSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.18, ms_mae_val, width=0.3, color='black', edgecolor='black', 
       label='Validation')
ax.bar(x + 0.18, ms_mae_test, width=0.3, color='white', edgecolor='black',
       hatch='/', label='Test')
ax.set_ylabel('Mean Absolute Error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
  plt.text(x=index - 0.18, y=value+0.0025, s=str(round(value, 3)),
           ha='center')
  
for index, value in enumerate(ms_mae_test):
  plt.text(x=index + 0.18, y=value+0.0025, s=str(round(value, 3)),
           ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig(f'{images_dir}/compare_single_step_models', dpi=300)
